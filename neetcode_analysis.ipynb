# %%
# !git clone https://github.com/neetcode-gh/leetcode.git

# %%
# !pip install libcst
# !pip install bertopic
# !pip install openai

# %%
import os
import pandas as pd
import libcst as cst

def parse_python_files(folder_path: str):
    """
    Loop through a folder, for every Python file parse the file using libcst,
    and then store in a pandas dataframe with columns (filename, code, libcst tree).

    Args:
    - folder_path (str): Path to the directory containing Python files.

    Returns:
    - pd.DataFrame: DataFrame with columns (filename, code, libcst tree).
    """

    # Initializing lists to hold data
    filenames = []
    codes = []
    libcst_trees = []

    # Loop through each file in the specified folder
    for root, _, files in os.walk(folder_path):
        for file in files:
            # Check if the file is a Python file
            if file.endswith('.py'):
                file_path = os.path.join(root, file)

                # Reading the file content
                with open(file_path, 'r', encoding='utf-8') as f:
                    code = f.read()

                # Parsing the code using libcst
                try:
                    tree = cst.parse_module(code)
                    # Appending data to the lists
                    filenames.append(file_path.split('/')[-1])
                    codes.append(code)
                    libcst_trees.append(tree)
                except Exception as e:
                    print(f"Error parsing {file_path}: {e}")

    # Creating a pandas DataFrame
    df = pd.DataFrame({
        'filename': filenames,
        'code': codes,
        'libcst_tree': libcst_trees
    })

    return df

# %%
df = parse_python_files("/content/leetcode/python")

# %%
df
# Out:
#                                               filename  \
# 0              0703-kth-largest-element-in-a-stream.py
# 1                 2390-removing-stars-from-a-string.py
# 2                               0355-design-twitter.py
# 3    0105-construct-binary-tree-from-preorder-and-i...
# 4                            0901-online-stock-span.py
# ..                                                 ...
# 328                            0740-delete-and-earn.py
# 329                                  0146-lru-cache.py
# 330                            0474-ones-and-zeroes.py
# 331                         0088-merge-sorted-array.py
# 332            1822-sign-of-the-product-of-an-array.py
#
#                                                   code  \
# 0    class KthLargest:\n    def __init__(self, k: i...
# 1    # https://leetcode.com/problems/removing-stars...
# 2    class Twitter:\n    def __init__(self):\n     ...
# 3    class Solution:\n    def buildTree(self, preor...
# 4    class StockSpanner:\n    def __init__(self):\n...
# ..                                                 ...
# 328  # House Robber Style\n# Time Complexity O(n)\n...
# 329  class Node:\n    def __init__(self, key, val):...
# 330  class Solution:\n    def findMaxForm(self, str...
# 331  class Solution:\n    def merge(self, nums1: Li...
# 332  class Solution:\n    def arraySign(self, nums:...
#
#                                            libcst_tree
# 0    Module(\n    body=[\n        ClassDef(\n      ...
# 1    Module(\n    body=[\n        ClassDef(\n      ...
# 2    Module(\n    body=[\n        ClassDef(\n      ...
# 3    Module(\n    body=[\n        ClassDef(\n      ...
# 4    Module(\n    body=[\n        ClassDef(\n      ...
# ..                                                 ...
# 328  Module(\n    body=[\n        ClassDef(\n      ...
# 329  Module(\n    body=[\n        ClassDef(\n      ...
# 330  Module(\n    body=[\n        ClassDef(\n      ...
# 331  Module(\n    body=[\n        ClassDef(\n      ...
# 332  Module(\n    body=[\n        ClassDef(\n      ...
#
# [333 rows x 3 columns]

# %% [markdown]
# ## Count Data Structures

# %%
import libcst as cst

class DataStructureCounter(cst.CSTVisitor):
    """
    Visitor class to count the number of data structures used in Python code.
    """

    def __init__(self):
        super().__init__()
        self.list_count = 0
        self.tuple_count = 0
        self.set_count = 0
        self.dict_count = 0

    def visit_List(self, node: cst.List) -> None:
        """
        Visit all list nodes.
        """
        self.list_count += 1

    def visit_Tuple(self, node: cst.Tuple) -> None:
        """
        Visit all tuple nodes.
        """
        self.tuple_count += 1

    def visit_Set(self, node: cst.Set) -> None:
        """
        Visit all set nodes.
        """
        self.set_count += 1

    def visit_Dict(self, node: cst.Dict) -> None:
        """
        Visit all dictionary nodes.
        """
        self.dict_count += 1


def count_data_structures_in_code(code: str) -> dict:
    """
    Count the number of data structures used in the given code.

    Args:
    - code (str): Python code.

    Returns:
    - dict: Dictionary containing counts of different data structures.
    """
    module = cst.parse_module(code)
    visitor = DataStructureCounter()
    module.visit(visitor)

    return {
        "list_count": visitor.list_count,
        "tuple_count": visitor.tuple_count,
        "set_count": visitor.set_count,
        "dict_count": visitor.dict_count
    }
def count_data_structures(df: pd.DataFrame) -> pd.DataFrame:
    """
    Process the given pandas DataFrame and add columns for counts of different
    data structures in the code column.

    Args:
    - df (pd.DataFrame): DataFrame with a 'code' column containing Python code.

    Returns:
    - pd.DataFrame: Updated DataFrame with additional columns for data structure counts.
    """

    # Apply the count_data_structures_in_code function to the 'code' column
    results = df['code'].apply(count_data_structures_in_code)

    # Convert the results to a DataFrame
    results_df = pd.DataFrame(results.tolist())

    # Concatenate the results to the original DataFrame
    df = pd.concat([df, results_df], axis=1)

    return df

# %%
df = count_data_structures(df)

# %%
df
# Out:
#                                               filename  \
# 0                          0097-interleaving-string.py
# 1                             0013-roman-to-integer.py
# 2                             0509-fibonacci-number.py
# 3    0211-design-add-and-search-words-data-structur...
# 4    1461-check-if-a-string-contains-all-binary-cod...
# ..                                                 ...
# 328            1822-sign-of-the-product-of-an-array.py
# 329                             0268-missing-number.py
# 330            0516-longest-palindromic-subsequence.py
# 331                                  0155-min-stack.py
# 332                                       0015-3sum.py
#
#                                                   code  \
# 0    class Solution:\n    def isInterleave(self, s1...
# 1    class Solution:\n    def romanToInt(self, s: s...
# 2    class Solution:\n    Memo = {}\n\n    def fib(...
# 3    class TrieNode:\n    def __init__(self):\n    ...
# 4    class Solution:\n    def hasAllCodes(self, s: ...
# ..                                                 ...
# 328  class Solution:\n    def arraySign(self, nums:...
# 329  class Solution:\n    def missingNumber(self, n...
# 330  # Time: O(n^2) Space: O(n^2) - For all three s...
# 331  class MinStack:\n    def __init__(self):\n    ...
# 332  class Solution:\n    def threeSum(self, nums: ...
#
#                                            libcst_tree  list_count  \
# 0    Module(\n    body=[\n        ClassDef(\n      ...           1
# 1    Module(\n    body=[\n        ClassDef(\n      ...           0
# 2    Module(\n    body=[\n        ClassDef(\n      ...           0
# 3    Module(\n    body=[\n        ClassDef(\n      ...           0
# 4    Module(\n    body=[\n        ClassDef(\n      ...           0
# ..                                                 ...         ...
# 328  Module(\n    body=[\n        ClassDef(\n      ...           0
# 329  Module(\n    body=[\n        ClassDef(\n      ...           0
# 330  Module(\n    body=[\n        ClassDef(\n      ...           2
# 331  Module(\n    body=[\n        ClassDef(\n      ...           2
# 332  Module(\n    body=[\n        ClassDef(\n      ...           2
#
#      tuple_count  set_count  dict_count
# 0              0          0           0
# 1              0          0           1
# 2              0          0           1
# 3              0          0           1
# 4              0          0           0
# ..           ...        ...         ...
# 328            0          0           0
# 329            0          0           0
# 330            7          0           1
# 331            0          0           0
# 332            3          0           0
#
# [333 rows x 7 columns]

# %%
def print_code_from_row(df: pd.DataFrame, row_index: int) -> None:
    """
    Print the contents of the 'code' column for the given row index.

    Args:
    - df (pd.DataFrame): DataFrame containing the 'code' column.
    - row_index (int): The index of the row to print the code from.

    Returns:
    - None: The function prints the code and doesn't return anything.
    """
    try:
        code_content = df.loc[row_index, 'code']
        print(code_content)
    except KeyError:
        print(f"Row index {row_index} not found in the DataFrame.")
    except Exception as e:
        print(f"An error occurred: {e}")

print_code_from_row(df, 330)
# Out:
# # Time: O(n^2) Space: O(n^2) - For all three solutions
# class Solution:
#     def longestPalindromeSubseq(self, s: str) -> int:
#         # Dynamic Programming
#         dp = [ [0] * (len(s) + 1) for i in range(len(s) + 1)]
#         res = 0
#
#         for i in range(len(s)):
#             for j in range(len(s) - 1, i - 1, -1):
#                 if s[i] == s[j]:
#                     dp[i][j] = 1 if i == j else 2
#                     if i - 1 >= 0:
#                         dp[i][j] += dp[i - 1][j + 1]
#                 else:
#                     dp[i][j] = dp[i][j + 1]
#                     if i - 1 >= 0:
#                         dp[i][j] = max(dp[i][j], dp[i - 1][j])
#                 res = max(res, dp[i][j])
#         return res
#
#
#         # Memoization
#         cache = {}
#
#         def dfs(i, j):
#             if i < 0 or j == len(s):
#                 return 0
#             if (i, j) in cache:
#                 return cache[(i, j)]
#
#             if s[i] == s[j]:
#                 length = 1 if i == j else 2
#                 cache[(i, j)] = length + dfs(i - 1, j + 1)
#             else:
#                 cache[(i, j)] = max(dfs(i - 1, j), dfs(i, j + 1))
#             return cache[(i, j)]
#
#         for i in range(len(s)):
#             dfs(i, i) # odd length
#             dfs(i, i + 1) # even length
#
#         return max(cache.values())
#
# # LCS Solution
# class Solution:
#     def longestPalindromeSubseq(self, s: str) -> int:
#         return self.longestCommonSubsequence(s, s[::-1])
#
#
#     def longestCommonSubsequence(self, s1: str, s2: str) -> int:
#         N, M = len(s1), len(s2)
#         dp = [[0] * (M+1) for _ in range(N+1)]
#
#         for i in range(N):
#             for j in range(M):
#                 if s1[i] == s2[j]:
#                     dp[i+1][j+1] = 1 + dp[i][j]
#                 else:
#                     dp[i+1][j+1] = max(dp[i][j+1], dp[i+1][j])
#         return dp[N][M]

# %% [markdown]
# ## Detect Recursion

# %%
df = parse_python_files("/content/leetcode/python")

# %%
import libcst as cst

class RecursiveFunctionDetector(cst.CSTVisitor):
    def __init__(self):
        self.current_function_name = None
        self.recursive_functions = set()


    def visit_FunctionDef(self, node: cst.FunctionDef) -> None:
        # Set the current function name
        self.current_function_name = node.name.value

    def leave_FunctionDef(self, node: cst.FunctionDef) -> None:
        # Reset the current function name after leaving the function
        self.current_function_name = None

    def visit_Call(self, node: cst.Call) -> None:
        if self.current_function_name is not None:
            # Check if the called function has the same name as the current function
            if isinstance(node.func, cst.Name) and node.func.value == self.current_function_name:
                self.recursive_functions.add(self.current_function_name)

def detect_recursive_functions(code: str) -> set:
    """
    Detect direct recursive functions in the given code.

    Args:
    - code (str): Python code as a string.

    Returns:
    - set: Set of function names that are recursive.
    """
    module = cst.parse_module(code)
    uses_recursion = False
    visitor = RecursiveFunctionDetector()
    module.visit(visitor)
    if len(list(visitor.recursive_functions)) > 0:
        uses_recursion = True
    return {
        "uses_recursion": uses_recursion,
        "recursive_functions":visitor.recursive_functions
        }

def label_recursive_rows(df: pd.DataFrame) -> pd.DataFrame:
    """
    Process the given pandas DataFrame and add columns for counts of different
    data structures in the code column.

    Args:
    - df (pd.DataFrame): DataFrame with a 'code' column containing Python code.

    Returns:
    - pd.DataFrame: Updated DataFrame with additional columns for data structure counts.
    """

    # Apply the count_data_structures_in_code function to the 'code' column
    results = df['code'].apply(detect_recursive_functions)

    # Convert the results to a DataFrame
    results_df = pd.DataFrame(results.tolist())

    # Concatenate the results to the original DataFrame
    df = pd.concat([df, results_df], axis=1)

    return df

# %%
df = label_recursive_rows(df)

# %%
df[df['uses_recursion'] == True]
# Out:
#                                               filename  \
# 3    0211-design-add-and-search-words-data-structur...
# 10                        0110-balanced-binary-tree.py
# 17                                     0078-subsets.py
# 25   2002-maximum-product-of-the-length-of-two-pali...
# 38                                        0018-4sum.py
# ..                                                 ...
# 286           0698-partition-to-k-equal-sum-subsets.py
# 291                            0063-unique-paths-ii.py
# 297                            0039-combination-sum.py
# 302                               0077-combinations.py
# 330            0516-longest-palindromic-subsequence.py
#
#                                                   code  \
# 3    class TrieNode:\n    def __init__(self):\n    ...
# 10   # Definition for a binary tree node.\n# class ...
# 17   class Solution:\n    def subsets(self, nums: L...
# 25   """\nTime Complexity: O(2^N)\nSpace Complexity...
# 38   class Solution:\n    def fourSum(self, nums, t...
# ..                                                 ...
# 286  class Solution(object):\n    def canPartitionK...
# 291  class Solution:\n    def uniquePathsWithObstac...
# 297  class Solution:\n    def combinationSum(self, ...
# 302  class Solution:\n    def combine(self, n: int,...
# 330  # Time: O(n^2) Space: O(n^2) - For all three s...
#
#                                            libcst_tree  uses_recursion  \
# 3    Module(\n    body=[\n        ClassDef(\n      ...            True
# 10   Module(\n    body=[\n        ClassDef(\n      ...            True
# 17   Module(\n    body=[\n        ClassDef(\n      ...            True
# 25   Module(\n    body=[\n        SimpleStatementLi...            True
# 38   Module(\n    body=[\n        ClassDef(\n      ...            True
# ..                                                 ...             ...
# 286  Module(\n    body=[\n        ClassDef(\n      ...            True
# 291  Module(\n    body=[\n        ClassDef(\n      ...            True
# 297  Module(\n    body=[\n        ClassDef(\n      ...            True
# 302  Module(\n    body=[\n        ClassDef(\n      ...            True
# 330  Module(\n    body=[\n        ClassDef(\n      ...            True
#
#     recursive_functions
# 3                 {dfs}
# 10                {dfs}
# 17                {dfs}
# 25                 {dp}
# 38           {findNsum}
# ..                  ...
# 286         {backtrack}
# 291               {dfs}
# 297               {dfs}
# 302            {helper}
# 330               {dfs}
#
# [62 rows x 5 columns]

# %%
print_code_from_row(df[df['uses_recursion'] == True], 17)
# Out:
# class Solution:
#     def subsets(self, nums: List[int]) -> List[List[int]]:
#         res = []
#
#         subset = []
#
#         def dfs(i):
#             if i >= len(nums):
#                 res.append(subset.copy())
#                 return
#             # decision to include nums[i]
#             subset.append(nums[i])
#             dfs(i + 1)
#             # decision NOT to include nums[i]
#             subset.pop()
#             dfs(i + 1)
#
#         dfs(0)
#         return res

# %% [markdown]
# ## Topic modeling and Clustering

# %%
from google.colab import userdata

# %%
DEFAULT_PROMPT = """
This is a list of code where each collection of code describe a topic. After each collection of code, the name of the topic they represent is mentioned as a short-highly-descriptive title
Mention the different patterns and any other specific descriptors that the examples share
Arrays & Hashing
Two Pointers
Sliding Window
Stack
Binary Search
Linked List
Trees
Tries
Heap / Priority Queue
Backtracking
Graphs
Advanced Graphs
Divide and Conquer
1-D Dynamic Programming
2-D Dynamic Programming
Greedy
Intervals
Math & Geometry
Bit Manipulation

Topic:
Sample texts from this topic:
[DOCUMENTS]
Keywords: [KEYWORDS]
Topic name:"""

# %%
import openai
from bertopic import BERTopic
from bertopic.representation import OpenAI
from umap import UMAP
from hdbscan import HDBSCAN

hdbscan_model = HDBSCAN(min_cluster_size=5, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

umap_model = UMAP(n_neighbors=5, n_components=5, min_dist=0.0, metric='cosine')


# Fine-tune topic representations with GPT
openai.api_key = userdata.get('openai_key')
representation_model = OpenAI(model="gpt-4", chat=True,exponential_backoff=True)

# %%
representation_model.default_prompt_ = DEFAULT_PROMPT

# %%
topic_model = BERTopic(umap_model=umap_model, hdbscan_model=hdbscan_model, representation_model=representation_model)

# %%
docs = df['code'].to_list()
topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1     40                    -1_Python Programming Solutions
# 1       0     50  0_Dynamic Programming in String Manipulation a...
# 2       1     26       1_Linked List Manipulation Methods in Python
# 3       2     23     2_Programming - Data Structures and Algorithms
# 4       3     23                      3_Binary Tree Node Operations
# 5       4     23  4_Coding Solutions for Array and List Manipula...
# 6       5     21     5_Programming Solutions for Various Algorithms
# 7       6     20               6_Binary Search Algorithms in Python
# 8       7     15  7_Python Coding Solutions for Array and String...
# 9       8     13  8_Manipulation and Analysis of 2D Grids in Python
# 10      9     13    9_Word Processing & Search Algorithms in Python
# 11     10     10  10_Binary Tree Operations using Depth-First Se...
# 12     11     10        11_Depth-First Search in Grids and Matrices
# 13     12     10                   12_Subarray Operations in Python
# 14     13      8                      13_Backtracking in Algorithms
# 15     14      8  14_Merging and Sorting Lists and Linked Lists ...
# 16     15      7   15_Programming Solutions and Complexity Analysis
# 17     16      7    16_Stack and Queue Operations in Python Classes
# 18     17      6          17_Meeting Interval Management Algorithms
#
#                                        Representation  \
# 0                      [Python Programming Solutions]
# 1   [Dynamic Programming in String Manipulation an...
# 2        [Linked List Manipulation Methods in Python]
# 3      [Programming - Data Structures and Algorithms]
# 4                       [Binary Tree Node Operations]
# 5   [Coding Solutions for Array and List Manipulat...
# 6      [Programming Solutions for Various Algorithms]
# 7                [Binary Search Algorithms in Python]
# 8   [Python Coding Solutions for Array and String ...
# 9   [Manipulation and Analysis of 2D Grids in Python]
# 10    [Word Processing & Search Algorithms in Python]
# 11  [Binary Tree Operations using Depth-First Search]
# 12         [Depth-First Search in Grids and Matrices]
# 13                    [Subarray Operations in Python]
# 14                       [Backtracking in Algorithms]
# 15  [Merging and Sorting Lists and Linked Lists in...
# 16    [Programming Solutions and Complexity Analysis]
# 17     [Stack and Queue Operations in Python Classes]
# 18           [Meeting Interval Management Algorithms]
#
#                                   Representative_Docs
# 0   [class Solution:\n    def findDisappearedNumbe...
# 1   [class Solution:\n    def findMaxForm(self, st...
# 2   [class Solution:\n    def pairSum(self, head: ...
# 3   [class Solution:\n    def reorganizeString(sel...
# 4   [# Definition for a binary tree node.\n# class...
# 5   [class Solution:\n    def majorityElement(self...
# 6   [class Solution:\n    def minSubArrayLen(self,...
# 7   [class Solution:\n    def findPeakElement(self...
# 8   [class Solution:\n    def removeElements(self,...
# 9   [class Solution:\n    def rotate(self, matrix:...
# 10  [class TrieNode:\n    def __init__(self):\n   ...
# 11  [# Definition for a binary tree node.\n# class...
# 12  [class Solution:\n    def maxAreaOfIsland(self...
# 13  [#We are basically storing sum%k and storing i...
# 14  [class Solution:\n    def subsetsWithDup(self,...
# 15  [# Definition for singly-linked list.\n# class...
# 16  [class Solution:\n    def multiply(self, num1:...
# 17  [class Solution(object):\n    def validateStac...
# 18  [class Solution:\n    """\n    @param interval...

# %%
topic_model.get_document_info(docs)
# Out:
#                                               Document  Topic  \
# 0    class KthLargest:\n    def __init__(self, k: i...      2
# 1    # https://leetcode.com/problems/removing-stars...      7
# 2    class Twitter:\n    def __init__(self):\n     ...      2
# 3    class Solution:\n    def buildTree(self, preor...      3
# 4    class StockSpanner:\n    def __init__(self):\n...     16
# ..                                                 ...    ...
# 328  # House Robber Style\n# Time Complexity O(n)\n...      7
# 329  class Node:\n    def __init__(self, key, val):...      1
# 330  class Solution:\n    def findMaxForm(self, str...      0
# 331  class Solution:\n    def merge(self, nums1: Li...     14
# 332  class Solution:\n    def arraySign(self, nums:...      6
#
#                                                   Name  \
# 0       2_Programming - Data Structures and Algorithms
# 1    7_Python Coding Solutions for Array and String...
# 2       2_Programming - Data Structures and Algorithms
# 3                        3_Binary Tree Node Operations
# 4      16_Stack and Queue Operations in Python Classes
# ..                                                 ...
# 328  7_Python Coding Solutions for Array and String...
# 329       1_Linked List Manipulation Methods in Python
# 330  0_Dynamic Programming in String Manipulation a...
# 331  14_Merging and Sorting Lists and Linked Lists ...
# 332               6_Binary Search Algorithms in Python
#
#                                         Representation  \
# 0       [Programming - Data Structures and Algorithms]
# 1    [Python Coding Solutions for Array and String ...
# 2       [Programming - Data Structures and Algorithms]
# 3                        [Binary Tree Node Operations]
# 4       [Stack and Queue Operations in Python Classes]
# ..                                                 ...
# 328  [Python Coding Solutions for Array and String ...
# 329       [Linked List Manipulation Methods in Python]
# 330  [Dynamic Programming in String Manipulation an...
# 331  [Merging and Sorting Lists and Linked Lists in...
# 332               [Binary Search Algorithms in Python]
#
#                                    Representative_Docs  \
# 0    [class Solution:\n    def reorganizeString(sel...
# 1    [class Solution:\n    def removeElements(self,...
# 2    [class Solution:\n    def reorganizeString(sel...
# 3    [# Definition for a binary tree node.\n# class...
# 4    [class Solution(object):\n    def validateStac...
# ..                                                 ...
# 328  [class Solution:\n    def removeElements(self,...
# 329  [class Solution:\n    def pairSum(self, head: ...
# 330  [class Solution:\n    def findMaxForm(self, st...
# 331  [# Definition for singly-linked list.\n# class...
# 332  [class Solution:\n    def findPeakElement(self...
#
#                                            Top_n_words  Probability  \
# 0         Programming - Data Structures and Algorithms     1.000000
# 1    Python Coding Solutions for Array and String M...     1.000000
# 2         Programming - Data Structures and Algorithms     0.820472
# 3                          Binary Tree Node Operations     0.474709
# 4         Stack and Queue Operations in Python Classes     0.941423
# ..                                                 ...          ...
# 328  Python Coding Solutions for Array and String M...     1.000000
# 329         Linked List Manipulation Methods in Python     1.000000
# 330  Dynamic Programming in String Manipulation and...     1.000000
# 331  Merging and Sorting Lists and Linked Lists in ...     1.000000
# 332                 Binary Search Algorithms in Python     0.350217
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                       True
# ..                       ...
# 328                    False
# 329                    False
# 330                     True
# 331                    False
# 332                    False
#
# [333 rows x 8 columns]

# %%
hierarchical_topics = topic_model.hierarchical_topics(docs)
# Out:
# 100%|██████████| 17/17 [00:39<00:00,  2.31s/it]

# %% [markdown]
# gpt-4

# %%
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# .
# ├─Binary Tree Operations and Solutions
# │    ├─Linked List Manipulation in Python
# │    │    ├─■──Stack and Queue Operations in Python Classes ── Topic: 16
# │    │    └─Linked List Manipulation Methods in Python
# │    │         ├─■──Linked List Manipulation Methods in Python ── Topic: 1
# │    │         └─■──Merging and Sorting Lists and Linked Lists in Python ── Topic: 14
# │    └─Binary Tree Operations
# │         ├─■──Binary Tree Node Operations ── Topic: 3
# │         └─■──Binary Tree Operations using Depth-First Search ── Topic: 10
# └─Python Programming - Algorithm Solutions
#      ├─Programming Solutions Using Depth-First Search (DFS)
#      │    ├─■──Word Processing & Search Algorithms in Python ── Topic: 9
#      │    └─Grid Processing Algorithms in Python
#      │         ├─■──Depth-First Search in Grids and Matrices ── Topic: 11
#      │         └─■──Manipulation and Analysis of 2D Grids in Python ── Topic: 8
#      └─Python Programming - Solution Classes for Various Algorithms
#           ├─Python Programming - Algorithm Solutions
#           │    ├─Implementing Numerical Algorithms in Python Classes
#           │    │    ├─■──Backtracking in Algorithms ── Topic: 13
#           │    │    └─Binary Search and Array Manipulation in Python
#           │    │         ├─Binary Search in Python Algorithms
#           │    │         │    ├─■──Python Coding Solutions for Array and String Manipulation ── Topic: 7
#           │    │         │    └─■──Binary Search Algorithms in Python ── Topic: 6
#           │    │         └─■──Subarray Operations in Python ── Topic: 12
#           │    └─Python Algorithm Solutions
#           │         ├─Python Algorithm Implementation
#           │         │    ├─■──Programming - Data Structures and Algorithms ── Topic: 2
#           │         │    └─Python Solution Methods for Array Manipulation
#           │         │         ├─Programming Solutions for Data Manipulation in Python
#           │         │         │    ├─■──Coding Solutions for Array and List Manipulations ── Topic: 4
#           │         │         │    └─■──Dynamic Programming in String Manipulation and Analysis ── Topic: 0
#           │         │         └─■──Programming Solutions for Various Algorithms ── Topic: 5
#           │         └─■──Programming Solutions and Complexity Analysis ── Topic: 15
#           └─■──Meeting Interval Management Algorithms ── Topic: 17

# %% [markdown]
# gpt3.5-turbo

# %%
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# .
# ├─Binary Tree Operations
# │    ├─Linked List Operations
# │    │    ├─Stack Operations in Python
# │    │    │    ├─■──Programming Topics with Various Classes and Methods ── Topic: 19
# │    │    │    └─Stack Manipulation
# │    │    │         ├─■──Stack Manipulation ── Topic: 7
# │    │    │         └─■──Stack-based String Operations ── Topic: 17
# │    │    └─Linked List Operations in Python
# │    │         ├─■──Linked List Operations ── Topic: 0
# │    │         └─■──Merge and Sort Linked Lists ── Topic: 16
# │    └─Binary Tree Operations
# │         ├─■──Binary Tree Operations ── Topic: 2
# │         └─■──Binary Tree Topic ── Topic: 13
# └─Python coding
#      ├─Data Structures and Algorithms
#      │    ├─Python coding - board games and graph traversal
#      │    │    ├─■──Python grid manipulation methods ── Topic: 10
#      │    │    └─■──Python coding - Trie, Word Matching ── Topic: 9
#      │    └─Dynamic Programming
#      │         ├─■──Python String and List Manipulation Methods ── Topic: 5
#      │         └─■──Dynamic Programming with Caching and DFS ── Topic: 8
#      └─Python algorithms
#           ├─Array Operations and Algorithms
#           │    ├─Binary Search and Sorting Algorithms
#           │    │    ├─Recursive Backtracking with Dynamic Programming
#           │    │    │    ├─■──Python coding ── Topic: 18
#           │    │    │    └─■──Backtracking Algorithms ── Topic: 14
#           │    │    └─Binary Search Algorithms
#           │    │         ├─■──Binary Search Algorithms ── Topic: 3
#           │    │         └─■──Array Sum and Subarrays ── Topic: 11
#           │    └─Python Class Methods and List Operations
#           │         ├─Python algorithms and data structures
#           │         │    ├─■──Time Complexity, Space Complexity, rob, canPlaceFlowers, reverse ── Topic: 6
#           │         │    └─Python programming - Solution class and methods
#           │         │         ├─■──Python solution for max subarray sum, max array frequency, and majority element ── Topic: 1
#           │         │         └─■──Document Processing ── Topic: 12
#           │         └─■──Data Structures and Algorithms in Python ── Topic: 4
#           └─Meeting Rooms Profit Intervals
#                ├─■──Interval Operations ── Topic: 20
#                └─■──coding techniques ── Topic: 15
